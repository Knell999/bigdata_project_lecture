# %%
import pandas as pd

df = pd.read_csv('seoul_real_estate_m.csv')

df
# Out:
# C:\Users\crazy\AppData\Local\Temp\ipykernel_22424\67291803.py:3: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('seoul_real_estate_m.csv')
#        ACC_YEAR  SGG_CD SGG_NM  BJDONG_CD BJDONG_NM  LAND_GBN LAND_GBN_NM  \
# 0          2024   11230   동대문구      11000       이문동       1.0          대지
# 1          2024   11710    송파구      10800       문정동       1.0          대지
# 2          2024   11620    관악구      10200       신림동       1.0          대지
# 3          2024   11410   서대문구      11100       홍제동       1.0          대지
# 4          2024   11110    종로구      18300       평창동       1.0          대지
# ...         ...     ...    ...        ...       ...       ...         ...
# 99995      2022   11560   영등포구      12600     양평동2가       1.0          대지
# 99996      2022   11620    관악구      10100       봉천동       1.0          대지
# 99997      2022   11500    강서구      10400       가양동       1.0          대지
# ...

# %%
df['DEAL_YMD'] = pd.to_datetime(df['DEAL_YMD'])
df['month'] = df['DEAL_YMD'].dt.month

# %%
import pandas as pd

def save_dataframe(dataframe, file_path):
    dataframe.to_csv(file_path, index=False)
    print("Dataframe saved successfully!")

# %%
save_dataframe(df, 'seoul_real_estate_df.csv')
# Out:
# Dataframe saved successfully!
