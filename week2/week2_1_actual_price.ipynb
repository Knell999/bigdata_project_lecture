# %%
import requests
import json
import pandas as pd

serviceKey = 'PT7s57yQ6NYjF%2BK4IX03RFJISja7dPlVceXQn7%2Fm2DWnibRv2u9288PJ6m9t4hi6sH2A%2B8fa8AGF3nDiGmeZRw%3D%3D'
pageNo = 1
numOfRows = 10
LAWD_CD	= 11560
DEAL_YMD = 202304

url = f'http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev?serviceKey={serviceKey}&pageNo={pageNo}&numOfRows={numOfRows}&LAWD_CD={LAWD_CD}&DEAL_YMD={DEAL_YMD}'

response = requests.get(url)
response.text
# Out:
# '<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><거래금액>    96,000</거래금액><거래유형>중개거래</거래유형><건축년도>2002</건축년도><년>2023</년><도로명>도신로29길</도로명><도로명건물본번호코드>00028</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11560</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4154317</도로명코드><동>201</동><등기일자>23.06.30</등기일자><매도자> </매도자><매수자> </매수자><법정동> 영등포동</법정동><법정동본번코드>0647</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11560</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>영등포푸르지오</아파트><월>4</월><일>6</일><일련번호>11560-2</일련번호><전용면적>79.777</전용면적><중개사소재지>서울 영등포구</중개사소재지><지번>647</지번><지역코드>11560</지역코드><층>17</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    92,500</거래금액><거래유형>중개거래</거래유형><건축년도>2002</건축년도><년>2023</년><도로명>도신로29길</도로명><도로명건물본번호코드>00028</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11560</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4154317</도로명코드><동>107</동><등기일자>23.05.12</등기일자><매도자> </매도자><매수자> </매수자><법정동> 영등포동</법정동><법정동본번코드>0647</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11560</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>영등포푸르지오</아파트><월>4</월><일>13</일><일련번호>11560-2</일련번호><전용면적>73.133</전용면적><중개사소재지>서울 영등포구</중개사소재지><지번>647</지번><지역코드>11560</지역코드><층>21</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    84,000</거래금액><거래유형>중개거래</거래유형><건축년도>2002</건축년도><년>2023</년><도로명>도신로29길</도로명><도로명건물본번호코드>00028</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11560</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4154317</도로명코드><동>211</동><등기일자>23.05.17</등기일자><매도자> </매도자><매수자> </매수자><법정동> 영등포동</법정동><법정동본번코드>0647</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11560</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>영등포푸르지오</아파트><월>4</월><일>13</일><일련번호>11560-2</일련번호><전용면적>73.133</전용면적><중개사소재지>서울 영등포구</중개사소재지><지번>647</지번><지역코드>11560</지역코드><층>21</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    96,500</거래금액><거래유형>중개거래</거래유형><건축년도>2002</건축년도><년>2023</년><도로명>도신로29길</도로명><도로명건물본번호코드>00028</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11560</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4154317</도로명코드><동>214</동><등기일자>23.07.28</등기일자><매도자> </매도자><매수자> </매수자><법정동> 영등포동</법정동><법정동본번코드>0647</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11560</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>영등포푸르지오</아파트><월>4</월><일>15</일><일련번호>11560-2</일련번호><전용면적>73.133</전용면적><중개사소재지>서울 영등포구</중개사소재지><지번>647</지번><지역코드>11560</지역코드><층>19</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    89,000</거래금액><거래유형>중개거래</거래유형><건축년도>2002</건축년도><년>2023</년><도로명>도신로29길</도로명><도로명건물본번호코드>00028</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11560</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4154317</도로명코드><동>214</동><등기일자>23.06.30</등기일자><매도자> </매도자><매수자> </매수자><법정동> 영등포동</법정동><법정동본번코드>0647</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11560</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>영등포푸르지오</아파트><월>4</월><일>15</일><일련번호>11560-2</일련번호><전용면적>59.912</전용면적><중개사소재지>서울 영등포구</중개사소재지><지번>647</지번><지역코드>11560</지역코드><층>2</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    89,000</거래금액><거래유형>직거래</거래유형><건축년도>2002</건축년도><년>2023</년><도로명>도신로29길</도로명><도로명건물본번호코드>00028</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11560</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4154317</도로명코드><동>103</동><등기일자>23.04.21</등기일자><매도자> </매도자><매수자> </매수자><법정동> 영등포동</법정동><법정동본번코드>0647</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11560</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>영등포푸르지오</아파트><월>4</월><일>20</일><일련번호>11560-2</일련번호><전용면적>84.908</전용면적><중개사소재지> </중개사소재지><지번>647</지번><지역코드>11560</지역코드><층>18</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    12,000</거래금액><거래유형>중개거래</거래유형><건축년도>2012</건축년도><년>2023</년><도로명>경인로114길</도로명><도로명건물본번호코드>00012</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군 ...

# %%
response.url
# Out:
# 'http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev?serviceKey=PT7s57yQ6NYjF%2BK4IX03RFJISja7dPlVceXQn7%2Fm2DWnibRv2u9288PJ6m9t4hi6sH2A%2B8fa8AGF3nDiGmeZRw%3D%3D&pageNo=1&numOfRows=10&LAWD_CD=11560&DEAL_YMD=202304'

# %%
import xmltodict
contents = xmltodict.parse(response.text)
contents
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL SERVICE.'},
#   'body': {'items': {'item': [{'거래금액': '96,000',
#       '거래유형': '중개거래',
#       '건축년도': '2002',
#       '년': '2023',
#       '도로명': '도신로29길',
#       '도로명건물본번호코드': '00028',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11560',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4154317',
#       '동': '201',
#       '등기일자': '23.06.30',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '영등포동',
#       '법정동본번코드': '0647',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11560',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '영등포푸르지오',
#       '월': '4',
#       '일': '6',
#       '일련번호': '11560-2',
#       '전용면적': '79.777',
#       '중개사소재지': '서울 영등포구',
#       '지번': '647',
#       '지역코드': '11560',
#       '층': '17',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '92,500',
#       '거래유형': '중개거래',
#       '건축년도': '2002',
#       '년': '2023',
#       '도로명': '도신로29길',
#       '도로명건물본번호코드': '00028',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11560',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4154317',
#       '동': '107',
#       '등기일자': '23.05.12',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '영등포동',
#       '법정동본번코드': '0647',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11560',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '영등포푸르지오',
#       '월': '4',
#       '일': '13',
#       '일련번호': '11560-2',
#       '전용면적': '73.133',
#       '중개사소재지': '서울 영등포구',
#       '지번': '647',
#       '지역코드': '11560',
#       '층': '21',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '84,000',
#       '거래유형': '중개거래',
#       '건축년도': '2002',
#       '년': '2023',
#       '도로명': '도신로29길',
#       '도로명건물본번호코드': '00028',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11560',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4154317',
#       '동': '211',
#       '등기일자': '23.05.17',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '영등포동',
#       '법정동본번코드': '0647',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11560',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '영등포푸르지오',
#       '월': '4',
#       '일': '13',
#       '일련번호': '11560-2',
#       '전용면적': '73.133',
#       '중개사소재지': '서울 영등포구',
#       '지번': '647',
#       '지역코드': '11560',
#       '층': '21',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '96,500',
#       '거래유형': '중개거래',
#       '건축년도': '2002',
#       '년': '2023',
#       '도로명': '도신로29길',
#       '도로명건물본번호코드': '00028',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11560',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4154317',
#       '동': '214',
#       '등기일자': '23.07.28',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '영등포동',
#       '법정동본번코드': '0647',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11560',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '영등포푸르지오',
#       '월': '4',
#       '일': '15',
#       '일련번호': '11560-2',
#       '전용면적': '73.133',
#       '중개사소재지': '서울 영등포구',
#       '지번': '647',
#       '지역코드': '11560',
#       '층': '19',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '89,000',
#       '거래유형': '중개거래',
#       '건축년도': '2002',
#       '년': '2023',
#       '도로명': '도신로29길',
#       '도로명건물본번호코드': '00028',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11560',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4154317',
#       '동': '214',
#       '등기일자': '23.06.30',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '영등포동',
#       '법정동본번코드': '0647',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11560',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '영등포푸르지오',
#       '월': '4',
#       '일': '15',
#       '일련번호': '11560-2',
#       '전용면적': '59.912',
#       '중개사소재지': '서울 영등포구',
#       '지번': '647',
#       '지역코드': '11560',
#       '층': '2',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '89,000',
#       '거래유형': '직거래',
#       '건축년도': '2002',
#       '년': '2023',
#       '도로명': '도신로29길',
#       '도로명건물본번호코드': '00028',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11560',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4154317',
#       '동': '103',
#       '등기일자': '23.04.21',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '영등포동',
#       '법정동본번코드': '0647',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11560',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '영등포푸르지오',
#       '월': '4',
#       '일': '20',
#       '일련번호': '11560-2',
#       '전용면적': '84.908',
#       '중개사소재지': None,
#       '지번': '647',
#       '지역코드': '11560',
#       '층': '18',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '12,000',
#       '거래유형': '중개거래',
#       '건축년도': '2012',
#       '년': '2023',
#       '도로명': '경인로114길',
#       '도로명건물본번호코드': '00012',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11560',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4154044',
#       '동': None,
#       '등기일자': '23.05.25',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '영등포동1가',
#       '법정동본번코드': '0029',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11560',
#       '법정동읍면동코드': '10200',
#       '법정동지번코드': '1',
#       '아파트': '여의도의아침',
#       '월': '4',
#       '일': '3',
#       '일련번호': '11560-1558',
#       '전용면적': '12.38',
#       '중개사소재지': '서울 영등포구',
#       '지번': '29',
#       '지역코드': '11560',
#       '층': '5',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '21,000',
#       '거래유형': '직거래',
#       '건축년도': '2020',
#       '년': '2023',
#       '도로명': '경인로',
#       '도로명건물본번호코드': '00900',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11560',
#       '도로명일련번호코드': '00',
#       '도로명코드': '3000028',
#       '동': '102동',
#       '등기일자': '23.04.18',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '영등포동1가',
#       '법정동본번코드': '0094',
#       '법정동부번코드': '0002',
#       '법정동시군구코드': '11560',
#       '법정동읍면동코드': '10200',
#       '법정동지번코드': '1',
#       '아파트': '여의도더리브스타일',
#       '월': '4',
#       '일': '15',
#       '일련번호': '11560-2153',
#       '전용면적': '14.8376',
#       '중개사소재지': None,
#       '지번': '94-2',
#       '지역코드': '11560',
#       '층': '23',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '37,800',
#       '거래유형': '직거래',
#       '건축년도': '2022',
#       '년': '2023',
#       '도로명': '버드나루로',
#       '도로명건물본번호코드': '00005',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11560',
#       '도로명일련번호코드': '00',
#       '도로명지상지하코드': '0',
#       '도로명코드': '3118010',
#       '동': None,
#       '등기일자': '23.04.13',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '영등포동2가',
#       '법정동본번코드': '0139',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11560',
#       '법정동읍면동코드': '10300',
#       '법정동지번코드': '1',
#       '아파트': '여의도리미티오148',
#       '월': '4',
#       '일': '13',
#       '일련번호': '11560-2270',
#       '전용면적': '24.3859',
#       '중개사소재지': None,
#       '지번': '139',
#       '지역코드': '11560',
#       '층': '9',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '10,350',
#       '거래유형': '중개거래',
#       '건축년도': '2014',
#       '년': '2023',
#       '도로명': '영중로6길',
#       '도로명건물본번호코드': '00012',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11560',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4154816',
#       '동': '포레스트힐시티',
#       '등기일자': '23.04.11',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '영등포동3가',
#       '법정동본번코드': '0019',
#       '법정동부번코드': '0002',
#       '법정동시군구코드': '11560',
#       '법정동읍면동코드': '10400',
#       '법정동지번코드': '1',
#       '아파트': '포레스트힐시티',
#       '월': '4',
#       '일': '8',
#       '일련번호': '11560-1680',
#       '전용면적': '13.53',
#       '중개사소재지': '서울 영등포구',
#       '지번': '19-2',
#       '지역코드': '11560',
#       '층': '4',
#       '해제사유발생일': None,
#       '해제여부': None}]},
#    'numOfRows': '10',
#    'pageNo': '1',
#    'totalCount': '164'}}}

# %%
type(contents)
# Out:
# dict

# %%
con = contents['response']['body']['items']['item']
result = pd.DataFrame(con)
result
# Out:
#      거래금액  거래유형  건축년도     년      도로명 도로명건물본번호코드 도로명건물부번호코드 도로명시군구코드 도로명일련번호코드  \
# 0  96,000  중개거래  2002  2023   도신로29길      00028      00000    11560        01
# 1  92,500  중개거래  2002  2023   도신로29길      00028      00000    11560        01
# 2  84,000  중개거래  2002  2023   도신로29길      00028      00000    11560        01
# 3  96,500  중개거래  2002  2023   도신로29길      00028      00000    11560        01
# 4  89,000  중개거래  2002  2023   도신로29길      00028      00000    11560        01
# 5  89,000   직거래  2002  2023   도신로29길      00028      00000    11560        01
# 6  12,000  중개거래  2012  2023  경인로114길      00012      00000    11560        01
# 7  21,000   직거래  2020  2023      경인로      00900      00000    11560        00
# 8  37,800   직거래  2022  2023    버드나루로      00005      00000    11560        00
# 9  10,350  중개거래  2014  2023    영중로6길      00012      00000    11560        01
#
#   도로명지상지하코드  ...  월   일        일련번호     전용면적   중개사소재지    지번   지역코드   층  \
# 0         0  ...  4   6     11560-2   79.777  서울 영등포구   647  11560  17
# 1         0  ...  4  13     11560-2   73.133  서울 영등포구   647  11560  21
# 2         0  ...  4  13     11560-2   73.133  서울 영등포구   647  11560  21
# 3         0  ...  4  15     11560-2   73.133  서울 영등포구   647  11560  19
# 4         0  ...  4  15     11560-2   59.912  서울 영등포구   647  11560   2
# 5         0  ...  4  20     11560-2   84.908     None   647  11560  18
# 6         0  ...  4   3  11560-1558    12.38  서울 영등포구    29  11560   5
# 7       NaN  ...  4  15  11560-2153  14.8376     None  94-2  11560  23
# 8         0  ...  4  13  11560-2270  24.3859     None   139  11560   9
# 9         0  ...  4   8  11560-1680    13.53  서울 영등포구  19-2  11560   4
#
#   해제사유발생일  해제여부
# 0    None  None
# 1    None  None
# 2    None  None
# 3    None  None
# 4    None  None
# 5    None  None
# 6    None  None
# 7    None  None
# 8    None  None
# 9    None  None
#
# [10 rows x 32 columns]

# %%
result[['년','월','일','도로명','거래금액']]
# Out:
#       년  월   일      도로명    거래금액
# 0  2023  4   6   도신로29길  96,000
# 1  2023  4  13   도신로29길  92,500
# 2  2023  4  13   도신로29길  84,000
# 3  2023  4  15   도신로29길  96,500
# 4  2023  4  15   도신로29길  89,000
# 5  2023  4  20   도신로29길  89,000
# 6  2023  4   3  경인로114길  12,000
# 7  2023  4  15      경인로  21,000
# 8  2023  4  13    버드나루로  37,800
# 9  2023  4   8    영중로6길  10,350
