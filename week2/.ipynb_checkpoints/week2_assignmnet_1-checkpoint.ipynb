# %%
import requests
import json
import pandas as pd

API_KEY = '65704b69446372613731624c4b7a53'

# '서울시 건축물대장 법정동 코드정보' Open API를 할용하여 30개 데이터를 가져오기
url = f'http://openapi.seoul.go.kr:8088/{API_KEY}/json/bigCmpBjdongMgmInfo/1/30'
req = requests.get(url)
content = req.json()
content
# Out:
# {'bigCmpBjdongMgmInfo': {'list_total_count': 2355,
#   'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#   'row': [{'SIGUNGU_CD': '11680',
#     'BJDONG_CD': '10600',
#     'HJDONG_CD': '675',
#     'SIDO_NM': '서울특별시',
#     'SIGUNGU_NM': '강남구',
#     'BJDONG_NM': '대치동',
#     'HJDONG_NM': '개포3동',
#     'APPLY_STRT_DAY': '20221223',
#     'APPLY_EXP_DAY': '99991231'},
#    {'SIGUNGU_CD': '11680',
#     'BJDONG_CD': '11400',
#     'HJDONG_CD': '675',
#     'SIDO_NM': '서울특별시',
#     'SIGUNGU_NM': '강남구',
#     'BJDONG_NM': '일원동',
#     'HJDONG_NM': '개포3동',
#     'APPLY_STRT_DAY': '20221223',
#     'APPLY_EXP_DAY': '99991231'},
#    {'SIGUNGU_CD': '11680',
#     'BJDONG_CD': '10300',
#     'HJDONG_CD': '675',
#     'SIDO_NM': '서울특별시',
#     'SIGUNGU_NM': '강남구',
#     'BJDONG_NM': '개포동',
#     'HJDONG_NM': '개포3동',
#     'APPLY_STRT_DAY': '20221223',
#     'APPLY_EXP_DAY': '99991231'},
#    {'SIGUNGU_CD': '11740',
#     'BJDONG_CD': '10300',
#     'HJDONG_CD': '525',
#     'SIDO_NM': '서울특별시',
#     'SIGUNGU_NM': '강동구',
#     'BJDONG_NM': '상일동',
#     'HJDONG_NM': '상일제1동',
#     'APPLY_STRT_DAY': '20210701',
#     'APPLY_EXP_DAY': '99991231'},
#    {'SIGUNGU_CD': '11740',
#     'BJDONG_CD': '10300',
#     'HJDONG_CD': '526',
#     'SIDO_NM': '서울특별시',
#     'SIGUNGU_NM': '강동구',
#     'BJDONG_NM': '상일동',
#     'HJDONG_NM': '상일제2동',
#     'APPLY_STRT_DAY': '20210701',
#     'APPLY_EXP_DAY': '99991231'},
#    {'SIGUNGU_CD': '11290',
#     'BJDONG_CD': '10300',
#     'HJDONG_CD': '620',
#     'SIDO_NM': '서울특별시',
#     'SIGUNGU_NM': '성북구',
#     'BJDONG_NM': '돈암동',
#     'HJDONG_NM': '정릉제1동',
#     'APPLY_STRT_DAY': '20210315',
#     'APPLY_EXP_DAY': '99991231'},
#    {'SIGUNGU_CD': '11530',
#     'BJDONG_CD': '11200',
#     'HJDONG_CD': '800',
#     'SIDO_NM': '서울특별시',
#     'SIGUNGU_NM': '구로구',
#     'BJDONG_NM': '항동',
#     'HJDONG_NM': '항동',
#     'APPLY_STRT_DAY': '20200101',
#     'APPLY_EXP_DAY': '99991231'},
#    {'SIGUNGU_CD': '11305',
#     'BJDONG_CD': '10200',
#     'HJDONG_CD': '603',
#     'SIDO_NM': '서울특별시',
#     'SIGUNGU_NM': '강북구',
#     'BJDONG_NM': '번동',
#     'HJDONG_NM': '번2동',
#     'APPLY_STRT_DAY': '20190101',
#     'APPLY_EXP_DAY': '99991231'},
#    {'SIGUNGU_CD': '11305',
#     'BJDONG_CD': '10200',
#     'HJDONG_CD': '595',
#     'SIDO_NM': '서울특별시',
#     'SIGUNGU_NM': '강북구',
#     'BJDONG_NM': '번동',
#     'HJDONG_NM': '번1동',
#     'APPLY_STRT_DAY': '20190101',
#     'APPLY_EXP_DAY': '99991231'},
#    {'SIGUNGU_CD': '11305',
#     'BJDONG_CD': '10300',
#     'HJDONG_CD': '625',
#     'SIDO_NM': '서울특별시',
#     'SIGUNGU_NM': '강북구',
#     'BJDONG_NM': '수유동',
#     'HJDONG_NM': '수유2동',
#     'APPLY_STRT_DAY': '20190101',
#     'APPLY_EXP_DAY': '99991231'},
#    {'SIGUNGU_CD': '11305',
#     'BJDONG_CD': '10300',
#     'HJDONG_CD': '615',
#     'SIDO_NM': '서울특별시',
#     'SIGUNGU_NM': '강북구',
#     'BJDONG_NM': '수유동',
#     'HJDONG_NM': '수유1동',
#     'APPLY_STRT_DAY': '20190101',
#     'APPLY_EXP_DAY': '99991231'},
#    {'SIGUNGU_CD': '11305',
#     'BJDONG_CD': '10200',
#     'HJDONG_CD': '608',
#     'SIDO_NM': '서울특별시',
#     'SIGUNGU_NM': '강북구',
#     'BJDONG_NM': '번동',
#     'HJDONG_NM': '번3동',
#     'APPLY_STRT_DAY': '20190101',
#     'APPLY_EXP_DAY': '99991231'},
#    {'SIGUNGU_CD': '11305',
#     'BJDONG_CD': '10300',
#     'HJDONG_CD': '635',
#     'SIDO_NM': '서울특별시',
#     'SIGUNGU_NM': '강북구',
#     'BJDONG_NM': '수유동',
#     'HJDONG_NM': '수유3동',
#     'APPLY_STRT_DAY': '20190101',
#     'APPLY_EXP_DAY': '99991231'},
#    {'SIGUNGU_CD': '11410',
#     'BJDONG_CD': '11200',
#     'HJDONG_CD': '555',
#     'SIDO_NM': '서울특별시',
#     'SIGUNGU_NM': '서대문구',
#     'BJDONG_NM': '대현동',
#     'HJDONG_NM': '북아현동',
#     'APPLY_STRT_DAY': '20161109',
#     'APPLY_EXP_DAY': '99991231'},
#    {'SIGUNGU_CD': '11500',
#     'BJDONG_CD': '10800',
#     'HJDONG_CD': '630',
#     'SIDO_NM': '서울특별시',
#     'SIGUNGU_NM': '강서구',
#     'BJDONG_NM': '공항동',
#     'HJDONG_NM': '방화제1동',
#     'APPLY_STRT_DAY': '20160928',
#     'APPLY_EXP_DAY': '99991231'},
#    {'SIGUNGU_CD': '11500',
#     'BJDONG_CD': '10900',
#     'HJDONG_CD': '620',
#     'SIDO_NM': '서울특별시',
#     'SIGUNGU_NM': '강서구',
#     'BJDONG_NM': '방화동',
#     'HJDONG_NM': '공항동',
#     'APPLY_STRT_DAY': '20160928',
#     'APPLY_EXP_DAY': '99991231'},
#    {'SIGUNGU_CD': '11500',
#     'BJDONG_CD': '10500',
#     'HJDONG_CD': '630',
#     'SIDO_NM': '서울특별시',
#     'SIGUNGU_NM': '강서구',
#     'BJDONG_NM': '마곡동',
#     'HJDONG_NM': '방화제1동',
#     'APPLY_STRT_DAY': '20160928',
#     'APPLY_EXP_DAY': '99991231'},
#    {'SIGUNGU_CD': '11500',
#     'BJDONG_CD': '10500',
#     'HJDONG_CD': '620',
#     'SIDO_NM': '서울특별시',
#     'SIGUNGU_NM': '강서구',
#     'BJDONG_NM': '마곡동',
#     'HJDONG_NM': '공항동',
#     'APPLY_STRT_DAY': '20160928',
#     'APPLY_EXP_DAY': '99991231'},
#    {'SIGUNGU_CD': '11440',
#     'BJDONG_CD': '10200',
#     'HJDONG_CD': '610',
#     'SIDO_NM': '서울특별시',
#     'SIGUNGU_NM': '마포구',
#     'BJDONG_NM': '공덕동',
#     'HJDONG_NM': '염리동',
#     'APPLY_STRT_DAY': '20150723',
#     'APPLY_EXP_DAY': '99991231'},
#    {'SIGUNGU_CD': '11710',
#     'BJDONG_CD': '10900',
#     'HJDONG_CD': '647',
#     'SIDO_NM': '서울특별시',
#     'SIGUNGU_NM': '송파구',
#     'BJDONG_NM': '장지동',
#     'HJDONG_NM': '위례동',
#     'APPLY_STRT_DAY': '20150706',
#     'APPLY_EXP_DAY': '99991231'},
#    {'SIGUNGU_CD': '11710',
#     'BJDONG_CD': '11300',
#     'HJDONG_CD': '647',
#     'SIDO_NM': '서울특별시',
#     'SIGUNGU_NM': '송파구',
#     'BJDONG_NM': '거여동',
#     'HJDONG_NM': '위례동',
#     'APPLY_STRT_DAY': '20150706',
#     'APPLY_EXP_DAY': '99991231'},
#    {'SIGUNGU_CD': '11710',
#     'BJDONG_CD': '10800',
#     'HJDONG_CD': '647',
#     'SIDO_NM': '서울특별시',
#     'SIGUNGU_NM': '송파구',
#     'BJDONG_NM': '문정동',
#     'HJDONG_NM': '위례동',
#     'APPLY_STRT_DAY': '20150706',
#     'APPLY_EXP_DAY': '20161128'},
#    {'SIGUNGU_CD': '11500',
#     'BJDONG_CD': '10400',
#     'HJDONG_CD': '510',
#     'SIDO_NM': '서울특별시',
#     'SIGUNGU_NM': '강서구',
#     'BJDONG_NM': '가양동',
#     'HJDONG_NM': '염창동',
#     'APPLY_STRT_DAY': '20150508',
#     'APPLY_EXP_DAY': '99991231'},
#    {'SIGUNGU_CD': '11230',
#     'BJDONG_CD': '10400',
#     'HJDONG_CD': '600',
#     'SIDO_NM': '서울특별시',
#     'SIGUNGU_NM': '동대문구',
#     'BJDONG_NM': '전농동',
#     'HJDONG_NM': '답십리제1동',
#     'APPLY_STRT_DAY': '20141030',
#     'APPLY_EXP_DAY': '20150712'},
#    {'SIGUNGU_CD': '11500',
#     'BJDONG_CD': '10500',
#     'HJDONG_CD': '611',
#     'SIDO_NM': '서울특별시',
#     'SIGUNGU_NM': '강서구',
#     'BJDONG_NM': '마곡동',
#     'HJDONG_NM': '발산제1동',
#     'APPLY_STRT_DAY': '20140514',
#     'APPLY_EXP_DAY': '99991231'},
#    {'SIGUNGU_CD': '11140',
#     'BJDONG_CD': '16200',
#     'HJDONG_CD': '665',
#     'SIDO_NM': '서울특별시',
#     'SIGUNGU_NM': '중구',
#     'BJDONG_NM': '신당동',
#     'HJDONG_NM': '동화동',
#     'APPLY_STRT_DAY': '20130720',
#     'APPLY_EXP_DAY': '99991231'},
#    {'SIGUNGU_CD': '11140',
#     'BJDONG_CD': '16200',
#     'HJDONG_CD': '645',
#     'SIDO_NM': '서울특별시',
#     'SIGUNGU_NM': '중구',
#     'BJDONG_NM': '신당동',
#     'HJDONG_NM': '청구동',
#     'APPLY_STRT_DAY': '20130720',
#     'APPLY_EXP_DAY': '99991231'},
#    {'SIGUNGU_CD': '11140',
#     'BJDONG_CD': '16200',
#     'HJDONG_CD': '635',
#     'SIDO_NM': '서울특별시',
#     'SIGUNGU_NM': '중구',
#     'BJDONG_NM': '신당동',
#     'HJDONG_NM': '약수동',
#     'APPLY_STRT_DAY': '20130720',
#     'APPLY_EXP_DAY': '99991231'},
#    {'SIGUNGU_CD': '11140',
#     'BJDONG_CD': '16200',
#     'HJDONG_CD': '625',
#     'SIDO_NM': '서울특별시',
#     'SIGUNGU_NM': '중구',
#     'BJDONG_NM': '신당동',
#     'HJDONG_NM': '다산동',
#     'APPLY_STRT_DAY': '20130720',
#     'APPLY_EXP_DAY': '99991231'},
#    {'SIGUNGU_CD': '11140',
#     'BJDONG_CD': '16400',
#     'HJDONG_CD': '615',
#     'SIDO_NM': '서울특별시',
#     'SIGUNGU_NM': '중구',
#     'BJDONG_NM': '무학동',
#     'HJDONG_NM': '신당동',
#     'APPLY_STRT_DAY': '20130720',
#     'APPLY_EXP_DAY': '99991231'}]}}

# %%
# 영등포구 2023년 실거래 데이터 100개 정보를 dataframe으로 만들고 확인
con = content['bigCmpBjdongMgmInfo']['row']
result = pd.DataFrame(con)
result.head()
# Out:
#   SIGUNGU_CD BJDONG_CD HJDONG_CD SIDO_NM SIGUNGU_NM BJDONG_NM HJDONG_NM  \
# 0      11680     10600       675   서울특별시        강남구       대치동      개포3동
# 1      11680     11400       675   서울특별시        강남구       일원동      개포3동
# 2      11680     10300       675   서울특별시        강남구       개포동      개포3동
# 3      11740     10300       525   서울특별시        강동구       상일동     상일제1동
# 4      11740     10300       526   서울특별시        강동구       상일동     상일제2동
#
#   APPLY_STRT_DAY APPLY_EXP_DAY
# 0       20221223      99991231
# 1       20221223      99991231
# 2       20221223      99991231
# 3       20210701      99991231
# 4       20210701      99991231

# %%
# 서울시 구로구 법정동 코드 가져오기
result[result['SIGUNGU_NM'] == '구로구']
# Out:
#   SIGUNGU_CD BJDONG_CD HJDONG_CD SIDO_NM SIGUNGU_NM BJDONG_NM HJDONG_NM  \
# 6      11530     11200       800   서울특별시        구로구        항동        항동
#
#   APPLY_STRT_DAY APPLY_EXP_DAY
# 6       20200101      99991231
