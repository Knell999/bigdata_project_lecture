# %%
import requests
import json
import pandas as pd

KEY = '76744e525163726131303072746e6e6a'
TYPE = input('원하는 요청파일 타입을 입력하세요 (xml, xmlf, xls, json)')
SERVICE = 'tbLnOpendataRtmsV'
START_INDEX	= 1
END_INDEX = 100
ACC_YEAR = input('원하는 년도를 입력하세요 (EX. 2023)')
SGG_CD = 11500 #서울시 강서구 코드



url = f'http://openapi.seoul.go.kr:8088/{KEY}/json/{SERVICE}/{START_INDEX}/{END_INDEX}/{ACC_YEAR}/{SGG_CD}'

req = requests.get(url)
content = req.json()
content
# Out:
# 원하는 요청파일 타입을 입력하세요 (xml, xmlf, xls, json) json
# 원하는 년도를 입력하세요 (EX. 2023) 2023
# {'tbLnOpendataRtmsV': {'list_total_count': 5088,
#   'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#   'row': [{'ACC_YEAR': '2023',
#     'SGG_CD': '11500',
#     'SGG_NM': '강서구',
#     'BJDONG_CD': '10300',
#     'BJDONG_NM': '화곡동',
#     'LAND_GBN': '1',
#     'LAND_GBN_NM': '대지',
#     'BONBEON': '1081',
#     'BUBEON': '0006',
#     'BLDG_NM': '드림파크빌',
#     'DEAL_YMD': '20231230',
#     'OBJ_AMT': '24000',
#     'BLDG_AREA': 58.26,
#     'TOT_AREA': 33.28,
#     'FLOOR': 5.0,
#     'RIGHT_GBN': '',
#     'CNTL_YMD': '',
#     'BUILD_YEAR': '2011',
#     'HOUSE_TYPE': '연립다세대',
#     'REQ_GBN': '중개거래',
#     'RDEALER_LAWDNM': '서울 강서구'},
#    {'ACC_YEAR': '2023',
#     'SGG_CD': '11500',
#     'SGG_NM': '강서구',
#     'BJDONG_CD': '10900',
#     'BJDONG_NM': '방화동',
#     'LAND_GBN': '1',
#     'LAND_GBN_NM': '대지',
#     'BONBEON': '0612',
#     'BUBEON': '0000',
#     'BLDG_NM': '마곡킹덤펜타리움',
# ...

# %%
type(content)
# Out:
# dict

# %%
content['tbLnOpendataRtmsV'].keys()
# Out:
# dict_keys(['list_total_count', 'RESULT', 'row'])

# %%
content['tbLnOpendataRtmsV']['row'][0]
# Out:
# {'ACC_YEAR': '2023',
#  'SGG_CD': '11500',
#  'SGG_NM': '강서구',
#  'BJDONG_CD': '10300',
#  'BJDONG_NM': '화곡동',
#  'LAND_GBN': '1',
#  'LAND_GBN_NM': '대지',
#  'BONBEON': '1081',
#  'BUBEON': '0006',
#  'BLDG_NM': '드림파크빌',
#  'DEAL_YMD': '20231230',
#  'OBJ_AMT': '24000',
#  'BLDG_AREA': 58.26,
#  'TOT_AREA': 33.28,
#  'FLOOR': 5.0,
#  'RIGHT_GBN': '',
#  'CNTL_YMD': '',
#  'BUILD_YEAR': '2011',
#  'HOUSE_TYPE': '연립다세대',
#  'REQ_GBN': '중개거래',
#  'RDEALER_LAWDNM': '서울 강서구'}

# %%
len(content['tbLnOpendataRtmsV']['row'])
# Out:
# 100

# %%
con = content['tbLnOpendataRtmsV']['row']
result = pd.DataFrame(con)
result.head()
# Out:
#   ACC_YEAR SGG_CD SGG_NM BJDONG_CD BJDONG_NM LAND_GBN LAND_GBN_NM BONBEON  \
# 0     2023  11500    강서구     10300       화곡동        1          대지    1081
# 1     2023  11500    강서구     10900       방화동        1          대지    0612
# 2     2023  11500    강서구     10300       화곡동        1          대지    0056
# 3     2023  11500    강서구     10300       화곡동        1          대지    0151
# 4     2023  11500    강서구     10100       염창동        1          대지    0253
#
#   BUBEON     BLDG_NM  ... OBJ_AMT BLDG_AREA  TOT_AREA  FLOOR  RIGHT_GBN  \
# 0   0006       드림파크빌  ...   24000     58.26     33.28    5.0
# 1   0000    마곡킹덤펜타리움  ...   28000     23.53      7.94   10.0
# 2   0594  파랑새빌라트(A동)  ...   24400     73.13     35.55    2.0
# 3   0008  힐타운(151-8)  ...   18000     46.25     22.82    3.0
# 4   0007       링크253  ...   40000     40.74     19.21    3.0
#
#   CNTL_YMD BUILD_YEAR HOUSE_TYPE REQ_GBN RDEALER_LAWDNM
# 0                2011      연립다세대    중개거래         서울 강서구
# ...

# %%
result['DEAL_YMD'].head()
# Out:
# 0    20231230
# 1    20231229
# 2    20231229
# 3    20231229
# 4    20231229
# Name: DEAL_YMD, dtype: object
