# %%
import requests
import json
import pandas as pd

API_KEY = '65704b69446372613731624c4b7a53'

# '서울시 건축물대장 법정동 코드정보' Open API를 할용하여 30개 데이터를 가져오기
url = f'http://openapi.seoul.go.kr:8088/{API_KEY}/json/bigCmpBjdongMgmInfo/1/100'
req = requests.get(url)
content = req.json()
content
# Out:
# {'bigCmpBjdongMgmInfo': {'list_total_count': 2355,
#   'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#   'row': [{'SIGUNGU_CD': '11680',
#     'BJDONG_CD': '11400',
#     'HJDONG_CD': '675',
#     'SIDO_NM': '서울특별시',
#     'SIGUNGU_NM': '강남구',
#     'BJDONG_NM': '일원동',
#     'HJDONG_NM': '개포3동',
#     'APPLY_STRT_DAY': '20221223',
#     'APPLY_EXP_DAY': '99991231'},
#    {'SIGUNGU_CD': '11680',
#     'BJDONG_CD': '10300',
#     'HJDONG_CD': '675',
#     'SIDO_NM': '서울특별시',
#     'SIGUNGU_NM': '강남구',
#     'BJDONG_NM': '개포동',
#     'HJDONG_NM': '개포3동',
#     'APPLY_STRT_DAY': '20221223',
#     'APPLY_EXP_DAY': '99991231'},
#    {'SIGUNGU_CD': '11680',
#     'BJDONG_CD': '10600',
#     'HJDONG_CD': '675',
#     'SIDO_NM': '서울특별시',
#     'SIGUNGU_NM': '강남구',
#     'BJDONG_NM': '대치동',
#     'HJDONG_NM': '개포3동',
#     'APPLY_STRT_DAY': '20221223',
#     'APPLY_EXP_DAY': '99991231'},
#    {'SIGUNGU_CD': '11740',
#     'BJDONG_CD': '10300',
#     'HJDONG_CD': '526',
# ...

# %%
# 영등포구 2023년 실거래 데이터 100개 정보를 dataframe으로 만들고 확인
con = content['bigCmpBjdongMgmInfo']['row']
result = pd.DataFrame(con)
result
# Out:
#    SIGUNGU_CD BJDONG_CD HJDONG_CD SIDO_NM SIGUNGU_NM BJDONG_NM HJDONG_NM  \
# 0       11680     11400       675   서울특별시        강남구       일원동      개포3동
# 1       11680     10300       675   서울특별시        강남구       개포동      개포3동
# 2       11680     10600       675   서울특별시        강남구       대치동      개포3동
# 3       11740     10300       526   서울특별시        강동구       상일동     상일제2동
# 4       11740     10300       525   서울특별시        강동구       상일동     상일제1동
# ..        ...       ...       ...     ...        ...       ...       ...
# 95      11500     10300       615   서울특별시        강서구       화곡동      우장산동
# 96      11230     10700       705   서울특별시       동대문구      청량리동      청량리동
# 97      11200     11300       645   서울특별시        성동구       옥수동       옥수동
# 98      11200     11000       615   서울특별시        성동구     금호동2가   금호2.3가동
# 99      11200     11100       615   서울특별시        성동구     금호동3가   금호2.3가동
#
#    APPLY_STRT_DAY APPLY_EXP_DAY
# 0        20221223      99991231
# ...

# %%
# 서울시 구로구 법정동 코드 가져오기
result[result['SIGUNGU_NM'] == '영등포구']
# Out:
#    SIGUNGU_CD BJDONG_CD HJDONG_CD SIDO_NM SIGUNGU_NM BJDONG_NM HJDONG_NM  \
# 54      11560     13200       515   서울특별시       영등포구       신길동     영등포본동
# 57      11560     12400       605   서울특별시       영등포구     문래동6가       문래동
# 58      11560     12300       605   서울특별시       영등포구     문래동5가       문래동
# 59      11560     12200       605   서울특별시       영등포구     문래동4가       문래동
# 60      11560     12100       605   서울특별시       영등포구     문래동3가       문래동
# 61      11560     12000       605   서울특별시       영등포구     문래동2가       문래동
# 62      11560     11900       605   서울특별시       영등포구     문래동1가       문래동
# 63      11560     11800       585   서울특별시       영등포구       도림동       도림동
# 64      11560     10900       535   서울특별시       영등포구    영등포동8가      영등포동
# 65      11560     10800       535   서울특별시       영등포구    영등포동7가      영등포동
# 66      11560     10700       535   서울특별시       영등포구    영등포동6가      영등포동
# 67      11560     10600       535   서울특별시       영등포구    영등포동5가      영등포동
# ...
